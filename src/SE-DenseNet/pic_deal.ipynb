# %%
import matplotlib.image as mpimg#读取图片
import matplotlib.pyplot as plt #显示图片
from PIL import Image
# %matplotlib inline

# %%
# %matplotlib inline
image = mpimg.imread('./examples/312_image.png')
plt.title('Read Image by Matplotlib')
plt.axis('off')# 不显示坐标轴
plt.imshow(image)
plt.show()

# %%
#现实图像处理，png转换为3通道
img_path = "./paperpic/ransacTest.png"
save_path = './realPics_t3/ransacTest_image.png'
 
img = Image.open(img_path)
img = img.convert("RGB") 
img.save(save_path)

# %%
#图像分割
